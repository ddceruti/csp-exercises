# %% [markdown]
# > This is the second of in total 3 exercises which are examinated within the lecture "Solarthermische Kraftwerke" at Technische Universität München

# %% [markdown]
# # Second Exercise

# %% [markdown]
# In this exercise we will have a more detailed look at the concentrating solar power plants which are installed around the globe.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.optimize import curve_fit
# To Visualize the data as map
import folium

# %% [markdown]
# > The first task is already done in this exercise. To get a better overview the location sites are plotted in the map below.
#
# > Click on the marker to get the name and the year of operation of the power plant. Add more details if needed.

# %%
# Load the data as pandas dataframe
df = pd.read_csv('./csp-guru/csp-guru/csp-guru.csv')
# fix wrong data
df.loc[122,'Year_construction_start'] = 2014

# %%
df_droped_nan =df
# Split location coordinates to latitude and longitude
df_droped_nan[['Latitude', 'Longitude']] = df_droped_nan['Location_coordinates'].str.split(',', expand=True)
# COnvert string to float
df_droped_nan[['Latitude','Longitude']].astype(float)
# Drop rows with missing/NaN values
df_droped_nan.dropna(subset=['Latitude', 'Longitude'], inplace=True)
# Plot Map with folium
map = folium.Map(location=[0, 0],zoom_start = 2)
for index,row in df_droped_nan.iterrows():
    folium.Marker(
        location= [row['Latitude'], row['Longitude']], 
        popup=folium.Popup(
            row['Power_station'] + " Year of Operation: " + str(row['Year_operational']),
            parse_html=True, max_width=100),
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d88b299d2f50be764c223f34f07168d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d88b299d2f50be764c223f34f07168d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d88b299d2f50be764c223f34f07168d7 = L.map(
#                 &quot;map_d88b299d2f50be764c223f34f07168d7&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d6ab210e79dbd73d0af204bd349d573 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9d6ab210e79dbd73d0af204bd349d573.addTo(map_d88b299d2f50be764c223f34f07168d7);
#
#
#             var marker_9f828446424011870a9456eea4589522 = L.marker(
#                 [34.863, -116.827],
#                 {
# }
#             ).addTo(map_d88b299d2f50be764c223f34f07168d7);
#
#
#         var popup_63225eab0bd1f0d263fc0bee229bff75 = L.popup({
#   &quot;maxWidth&quot;: 100,
# });
#
#
#
#                 var html_e9c2668abf66c8001c0ad86a676d170f = $(`&lt;div id=&quot;html_e9c2668abf66c8001c0ad86a676d170f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Solar Electric Generating Station I Year of Operation: 1984.0&lt;/div&gt;`)[0];
#                 popup_63225eab0bd1f0d263fc0bee229bff75.setContent(html_e9c2668abf66c8001c0ad86a676d170f);
#
#
#
#         marker_9f828446424011870a9456eea4589522.bindPopup(popup_63225eab0bd1f0d263fc0bee229bff75)
#         ;
#
#
#
#
#             var marker_68e20e8ed51ab5b75e8f21b5e51c6000 = L.marker(
#                 [34.863, -116.827],
#                 {
# }
#             ).addTo(map_d88b299d2f50be764c223f34f07168d7);
#
#
#         var popup_d9dd9c28ba1166272affecff2f54224c = L.popup({
#   &quot;maxWidth&quot;: 100,
# });
#
#
#
#                 var html_f13d10b2ede1597f9a17c68ad51d17be = $(`&lt;div id=&quot;html_f13d10b2ede1597f9a17c68ad51d17be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Solar Electric Generating Station II Year of Operation: 1985.0&lt;/div&gt;`)[0];
#                 popup_d9dd9c28ba1166272affecff2f54224c.setContent(html_f13d10b2ede1597f9a17c68ad51d17be);
#
#
#
#         marker_68e20e8ed51ab5b75e8f21b5e51c6000.bindPopup(popup_d9dd9c28ba1166272affecff2f54224c)
#         ;
#
#
#
#
#             var marker_31cc245e4bc52a369346e8205e4cf358 = L.marker(
#                 [35.014, -117.559],
#                 {
# }
#             ).addTo(map_d88b299d2f50be764c223f34f07168d7);
#
#
#         var popup_291199b8d86208771a4a7b51a4c9bcbe = L.popup({
#   &quot;maxWidth&quot;: 100,
# });
#
#
#
#                 var html_439cbe149a76ccb8d0f8aa58ce99f7ba = $(`&lt;div id=&quot;html_439cbe149a76ccb8d0f8aa58ce99f7ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Solar Electric Generating Station III Year of Operation: 1985.0&lt;/div&gt;`)[0];
#                 popup_291199b8d86208771a4a7b51a4c9bcbe.setContent(html_439cbe149a76ccb8d0f8aa58ce99f7ba);
#
#
#
#         marker_31cc245e4bc52a369346e8205e4cf358.bindPopup(popup_291199b8d86208771a4a7b51a4c9bcbe)
#         ;
#
#
#
#
#             var marker_3721daa4e214a277be77af4ff1ece6f6 = L.marker(
#                 [35.014, -117.559],
#                 {
# }
#             ).addTo(map_d88b299d2f50be764c223f34f07168d7);
#
#
#         var popup_683df8c6276cda5c8ba57cba1c4d345f = L.popup({
#   &quot;maxWidth&quot;: 100,
# });
#
#
#
#                 var html_29e9764dc83ea48c02ec8def4021d7f0 = $(`&lt;div id=&quot;html_29e9764dc83ea48c02ec8def4021d7f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Solar Electric Generating Station IV Year of Operation: 1989.0&lt;/div&gt;`)[0];
#                 popup_683df8c6276cda5c8ba57cba1c4d345f.setContent(html_29e9764dc83ea48c02ec8def4021d7f0);
#
#
#
#         marker_3721daa4e214a277be77af4ff1ece6f6.bindPopup(popup_683df8c6276cda5c8ba57cba1c4d345f)
#         ;
#
#
#
#
#             var marker_a78cbbb046310bb5f1da4959bc408ad8 = L.marker(
#                 [35.014, -117.559],
#                 {
# }
#             ).addTo(map_d88b299d2f50be764c223f34f07168d7);
#
#
#         var popup_578cfa94b19ef991d0861e8a9c484e07 = L.popup({
#   &quot;maxWidth&quot;: 100,
# });
#
#
#
#                 var html_5f60e024df9834ab982975938819d838 = $(`&lt;div id=&quot;html_5f60e024df9834ab982975938819d838&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Solar Electric Generating Station V Year of Operation: 1989.0&lt;/div&gt;`)[0];

# %% [markdown]
# ## 1. General Tasks

# %% [markdown]
# ### 1.1 How many entities does the dataset have?

# %%
# Number of entities
df.shape[0]
# Out:
# 135

# %% [markdown]
# ### 1.2 Visualize the data columns

# %%
print(df.columns)
# Out:
# Index(['Power_station', 'Local_spelling', 'OpenCSP_ID', 'Country', 'Region',
#        'Status', 'Capacity_MW', 'Expected_generation_GWh_per_yr',
#        'Capacity_factor', 'Technology', 'Hybridisation_capacity',
#        'Hybridisation_ratio', 'Hybridisation_comment',
#        'Year_construction_start', 'Year_operational',
#        'State_highest_administrative_level',
#        'Province_County_medium_administrative_level',
#        'City_lowest_administrative_level', 'Location_coordinates',
#        'DNI_kWh_per_m2_per_yr', 'Total_cost_million_currency_non_deflated',
#        'Cost_currency', 'Currency_year', 'Total_cost_million_USD2020',
#        'Specific_cost_USD2020_per_kW', 'LCOE_5_25_USD2020_per_kWh',
#        'Remuneration_currency_per_kWh', 'Support_currency',
#        'Cost_year_remuneration', 'Remuneration_USD2020_per_kWh_deflated',
#        'PPA_or_support_duration_yr', 'Support_scheme_type',
#        'Policy_support_scheme', 'Concessional_funding_other_support',
#        'Land_area_whole_station_not_solar_field_km2', 'Developer',
#        'Developer_country', 'First_owner', 'First_operator',
#        'Electricity_generation_offtaker', 'EPC', 'EPC_country',
#        'HTF_manufacturer', 'HTF_manufacturer_country', 'HTF_medium_or_product',
#        'HTF_category', 'Steam_turbine_manufacturer',
#        'Steam_turbine_manufacturer_country', 'Turbine_model',
#        'Turbine_thermodynamic_cycle', 'Power_cycle_pressure_bar',
#        'Turbine_efficiency_percent', 'Heat_exchanger_manufacturer',
#        'Heat_exchanger_manufacturer_country', 'Cooling_type',
#        'Energy_storage_type', 'Storage_capacity_hours', 'Storage_description',
#        'TES_engineering_company', 'TES_engineering_company_country',
#        'Solar_receiver_manufacturer', 'Solar_receiver_country',
#        'Solar_receiver_model', 'Tower_height_m',
#        'Number_of_heat_collecting_elements_for_trough_and_fresnel',
#        'Receiver_inlet_temperature_Celsius',
#        'Receiver_outlet_temperature_Celsius', 'SCA_or_heliostat_manufacturer',
#        'SCA_or_heliostat_manufacturer_country',
#        'SCA_or_heliostat_engineering_or_IP_owner_company',
#        'SCA_or_heliostat_engineering_or_IP_owner_company_country',
#        'SCA_or_heliostat_model', 'Reflector_mirror_manufacturer',
#        'Reflector_mirror_manufacturer_country', 'Reflector_model',
#        'Solar_mirror_area_m2', 'Solar_multiple',
#        'Number_of_heliostats_or_dishes', 'Mirror_area_per_heliostat_or_dish',
#        'Fresnel_line_width_m', 'Fresnel_number_of_lines',
#        'Fresnel_line_length_m', 'Trough_solar_collector_area_m2',
#        'Trough_SCA_length_m', 'Trough_number_of_loops',
#        'Trough_number_of_modules_per_SCA', 'Trough_number_of_SCA',
#        'Trough_number_of_SCA_per_loop', 'Construction_jobs_years',
#        'Annual_operations_jobs',
#        'Additional_sources_relative_to_2019_version_of_cspGURU_and_NRELSolarPACES_as_of_31_January_2020',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %% [markdown]
# ### 1.3 Group the dataset by 'Country' and have a look at the available entries. Are all entries always complete?

# %%
# Sorts Table by Country and count the number of entries
country_count = df.groupby(['Country']).count()
country_count = country_count.sort_values(by='Country', ascending=False)
# Saves a variable to open with i.e. Data Wrangler in VS Code
country_count
# Out:
#                       Power_station  Local_spelling  OpenCSP_ID  Region  \
# Country
# United States                    25               0          25      25
# United Arab Emirates              4               0           4       4
# Turkey                            1               0           1       1
# Thailand                          1               0           1       1
# Spain                            50               0          50      50
# South Africa                      7               0           7       7
# Saudi Arabia                      2               0           2       2
# Morocco                           4               0           4       4
# Mexico                            1               0           1       1
# Kuwait                            1               0           1       1
# Italy                             3               0           3       3
# Israel                            2               0           2       2
# India                             7               0           7       7
# Germany                           1               0           1       1
# France                            2               0           2       2
# Egypt                             1               0           1       1
# Denmark                           1               0           1       1
# China                            14              14          14      14
# Chile                             1               0           1       1
# Canada                            1               0           1       1
# Australia                         5               0           5       5
# Algeria                           1               0           1       1
#
#                       Status  Capacity_MW  Expected_generation_GWh_per_yr  \
# Country
# United States             25           25                              19
# United Arab Emirates       4            3                               1
# Turkey                     1            1                               0
# Thailand                   1            1                               1
# Spain                     50           50                              50
# South Africa               7            7                               7
# Saudi Arabia               2            2                               0
# Morocco                    4            4                               4
# Mexico                     1            1                               1
# Kuwait                     1            1                               1
# Italy                      3            3                               3
# Israel                     2            2                               2
# India                      7            7                               4
# Germany                    1            1                               0
# France                     2            2                               1
# Egypt                      1            1                               1
# Denmark                    1            1                               0
# China                     14           14                              13
# Chile                      1            1                               0
# Canada                     1            1                               1
# Australia                  5            5                               3
# Algeria                    1            1                               0
#
#                       Capacity_factor  Technology  Hybridisation_capacity  \
# Country
# United States                      19          25                       0
# United Arab Emirates                1           4                       1
# Turkey                              0           1                       0
# Thailand                            1           1                       0
# Spain                              50          50                       1
# South Africa                        7           7                       1
# Saudi Arabia                        0           2                       2
# Morocco                             4           4                       3
# Mexico                              1           1                       1
# Kuwait                              1           1                       1
# Italy                               3           3                       0
# Israel                              2           2                       0
# India                               4           7                       1
# Germany                             0           1                       0
# France                              1           2                       0
# Egypt                               1           1                       1
# Denmark                             0           1                       0
# China                              13          14                       1
# Chile                               0           1                       1
# Canada                              1           1                       1
# Australia                           3           5                       0
# Algeria                             0           1                       1
#
#                       ...  Trough_SCA_length_m  Trough_number_of_loops  \
# Country               ...
# United States         ...                    4                       4
# United Arab Emirates  ...                    1                       1
# Turkey                ...                    0                       0
# Thailand              ...                    1                       1
# Spain                 ...                   37                      44
# South Africa          ...                    0                       3
# Saudi Arabia          ...                    0                       0
# Morocco               ...                    2                       2
# Mexico                ...                    1                       1
# Kuwait                ...                    0                       0
# Italy                 ...                    1                       2
# Israel                ...                    0                       0
# India                 ...                    3                       4
# Germany               ...                    0                       0
# France                ...                    0                       0
# Egypt                 ...                    0                       1
# Denmark               ...                    1                       1
# China                 ...                    2                       2
# Chile                 ...                    0                       0
# Canada                ...                    1                       1
# Australia             ...                    0                       0
# Algeria               ...                    1                       1
#
#                       Trough_number_of_modules_per_SCA  Trough_number_of_SCA  \
# Country
# United States                                        5                     6
# United Arab Emirates                                 1                     1
# Turkey                                               0                     0
# Thailand                                             1                     1
# Spain                                               32                    45
# South Africa                                         1                     2
# Saudi Arabia                                         0                     0
# Morocco                                              1                     2
# Mexico                                               0                     1
# Kuwait                                               0                     0
# Italy                                                1                     2
# Israel                                               1                     0
# India                                                3                     3
# Germany                                              0                     0
# France                                               0                     0
# Egypt                                                1                     1
# Denmark                                              1                     1
# China                                                2                     1
# Chile                                                0                     0
# Canada                                               0                     1
# Australia                                            0                     0
# Algeria                                              0                     1
#
#                       Trough_number_of_SCA_per_loop  Construction_jobs_years  \
# Country
# United States                                     5                        7
# United Arab Emirates                              1                        0
# Turkey                                            0                        0
# Thailand                                          0                        1
# Spain                                            43                       33
# South Africa                                      2                        1
# Saudi Arabia                                      0                        0
# Morocco                                           2                        0
# Mexico                                            1                        0
# Kuwait                                            0                        0
# Italy                                             1                        0
# Israel                                            0                        1
# India                                             3                        0
# Germany                                           0                        0
# France                                            0                        1
# Egypt                                             1                        0
# Denmark                                           1                        0
# China                                             1                        6
# Chile                                             0                        0
# Canada                                            1                        0
# Australia                                         0                        0
# Algeria                                           1                        0
#
#                       Annual_operations_jobs  \
# Country
# United States                              7
# United Arab Emirates                       0
# Turkey                                     0
# Thailand                                   1
# Spain                                     36
# South Africa                               1
# Saudi Arabia                               0
# Morocco                                    0
# Mexico                                     0
# Kuwait                                     0
# Italy                                      0
# Israel                                     1
# India                                      0
# Germany                                    0
# France                                     1
# Egypt                                      0
# Denmark                                    0
# China                                      6
# Chile                                      0
# Canada                                     0
# Australia                                  0
# Algeria                                    0
#
#                       Additional_sources_relative_to_2019_version_of_cspGURU_and_NRELSolarPACES_as_of_31_January_2020  \
# Country
# United States                                                         8
# United Arab Emirates                                                  2
# Turkey                                                                0
# Thailand                                                              0
# Spain                                                                 0
# South Africa                                                          1
# Saudi Arabia                                                          1
# Morocco                                                               0
# Mexico                                                                0
# Kuwait                                                                0
# Italy                                                                 0
# Israel                                                                0
# India                                                                 1
# Germany                                                               0
# France                                                                0
# Egypt                                                                 0
# Denmark                                                               0
# China                                                                13
# Chile                                                                 1
# Canada                                                                0
# Australia                                                             1
# Algeria                                                               0
#
#                       Latitude  Longitude
# Country
# United States               25         25
# United Arab Emirates         4          4
# Turkey                       1          1
# Thailand                     1          1
# Spain                       50         50
# South Africa                 7          7
# Saudi Arabia                 2          2
# Morocco                      4          4
# Mexico                       1          1
# Kuwait                       1          1
# Italy                        3          3
# Israel                       2          2
# India                        7          7
# Germany                      1          1
# France                       2          2
# Egypt                        1          1
# Denmark                      1          1
# China                       14         14
# Chile                        1          1
# Canada                       1          1
# Australia                    5          5
# Algeria                      1          1
#
# [22 rows x 92 columns]

# %% [markdown]
# > Answer: Not for all locaiton sites all informaiton is available

# %% [markdown]
# ### 1.4 In your opinion, is the data availability on the CSP high?

# %% [markdown]
# > Yes, it is quite transparent. A lot of information has been tracked, i.e. general information of total energy generation, coordinates, year of construction. Additional to this information the inlet temperature of the collectors, the specific cycle for energy transition, the total cost for building and LCOE are often given. Therefore, the industry in the concentrating solar power plants can be quite transparent.

# %% [markdown]
# ### 1.5 Are there any new power plants, which are currently under construction, but not included in the dataset?

# %% [markdown]
# > https://www.solarpaces.org/
#
# Yes, especially in China, where there has been a very large expansion of CSP plants in the last years since the dataset was collected.

# %% [markdown]
# ### 2.1 Where are the most CSP installed? Why is this so?

# %%
[df['Country'].groupby(df['Country']).count().idxmax(), df['Country'].groupby(df['Country']).count().max()]
# Out:
# ['Spain', np.int64(50)]

# %%
df['Country'].value_counts()
# Out:
# Country
# Spain                   50
# United States           25
# China                   14
# India                    7
# South Africa             7
# Australia                5
# Morocco                  4
# United Arab Emirates     4
# Italy                    3
# Saudi Arabia             2
# France                   2
# Israel                   2
# Germany                  1
# Algeria                  1
# Thailand                 1
# Turkey                   1
# Egypt                    1
# Canada                   1
# Mexico                   1
# Denmark                  1
# Kuwait                   1
# Chile                    1
# Name: count, dtype: int64

# %% [markdown]
#  A little history:
#
# > "In September 2002, Spain was the first European country to introduce a “feed-in tariff” funding system for solar thermal power. This funding system granted a premium on top of the electricity pool price of 12 € cents for each kWh output of a solar thermal plant between 100 kW and 50 MW of capacity, which could be changed every four years. But this amount proved not bankable nor did it cover the cost and risks to make the first projects feasible.
# >The Royal Decree 436/2004 introduced two alternative remuneration options for new CSP installed capacity. Solar thermal electricity generators who sell their production to a distributor receive as fixed tariff 300% of the reference price (7.2 € cents/kWh) during the first 25 years and 240% afterwards.
# >Solar thermal electricity generators who sell their electricity on the free market receive the negotiated market price of electricity, a premium of 250% of the reference price during the first 25 years, 200% afterwards, and an incentive of 10%."
# Information taken from : https://www.solarpaces.org/worldwide-csp/csp-potential-solar-thermal-energy-by-country/spain/

# %% [markdown]
# ### 2.2 Which country has currently the biggest installed capacity of solar concentrating power plants? Try to visualize your results with `folium`

# %%
# Convert Latitude to numeric, coercing errors to NaN
df['Latitude'] = pd.to_numeric(df['Latitude'], errors='coerce')

# Group by Country and calculate mean Latitude
mean_latitude = df.groupby('Country')['Latitude'].mean().reset_index()

# %%
# Convert Latitude to numeric, coercing errors to NaN
df['Longitude'] = pd.to_numeric(df['Longitude'], errors='coerce')

# Group by Country and calculate mean Latitude
mean_longitude = df.groupby('Country')['Longitude'].mean().reset_index()
mean_coordinates = pd.merge(mean_latitude, mean_longitude, on='Country')

# %%
# Groub by Country and calculate the total capacity
country_capacity = df.groupby('Country')['Capacity_MW'].sum().reset_index()
# Sort the table descending
country_capacity = country_capacity.sort_values(by='Capacity_MW',
                                                ascending=False)
# Merge the two dataframes
country_capacity = pd.merge(country_capacity, mean_coordinates,
                            on='Country')
country_capacity.head(25)
# Out:
#                  Country  Capacity_MW   Latitude   Longitude
# 0                  Spain       2304.9  38.333440   -4.914180
# 1          United States       1805.8  34.360720 -116.450880
# 2   United Arab Emirates        800.0  24.462500   54.949000
# 3           South Africa        600.0 -28.513354   21.465312
# 4                  China        596.0  39.425342   99.767241
# 5                  India        342.5  25.986857   74.532143
# 6                Morocco        333.0  31.584000   -6.245500
# 7                 Israel        231.0  30.964500   34.706000
# 8                  Chile        110.0 -22.771000  -69.479000
# 9           Saudi Arabia         93.0  29.689800   37.162500
# 10                Kuwait         50.0  29.139000   47.018000
# 11                 Egypt         20.0  29.279000   31.249000
# 12               Algeria         20.0  33.124000    3.357000
# 13                Mexico         12.0  31.326000 -109.549000
# 14             Australia          9.6 -32.811600  146.865200
# 15                France          9.3  42.485000    2.017500
# 16                 Italy          6.1  39.746000   14.664000
# 17               Denmark          5.5  57.254000    9.989000
# 18              Thailand          5.0  14.334000   99.709000
# 19               Germany          1.5  50.915000    6.388000
# 20                Turkey          1.4  36.865000   34.610000
# 21                Canada          1.1  50.040000 -110.720000

# %%
# Function to determine the size of the icon
def get_icon_size(capacity):
    return max(capacity/10 ,15) # Scale size as needed

# Create a Folium map
map_total_capacity = folium.Map(location=[0, 0], zoom_start=2)

# Add markers with adjustable size
for index, row in country_capacity.iterrows():
    icon_size = get_icon_size(row['Capacity_MW'])
    
    # Set the anchor point for the icon based on the icon size
    icon_anchor = (icon_size / 35, icon_size*1.3)  # Centered horizontally, bottom anchored

    # Create a DivIcon with custom size and centering
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(f"{row['Country']} Installed Capacity MW: {row['Capacity_MW']}",
                           parse_html=True, max_width=100),
        icon=folium.DivIcon(
            html=f'<div style="font-size: {icon_size}px; color: blue; text-align: center; transform: translate(-50%, 0);">|</div>',  # Using a circle >⬤< character can also be used
            icon_size=(icon_size, icon_size),
            icon_anchor=icon_anchor
        )
    ).add_to(map_total_capacity)

# Display the map
map_total_capacity
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0038a8dac7fe5c8ddd2894ddfd630340 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0038a8dac7fe5c8ddd2894ddfd630340&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0038a8dac7fe5c8ddd2894ddfd630340 = L.map(
#                 &quot;map_0038a8dac7fe5c8ddd2894ddfd630340&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ebdcd13c344cb6fc2d08d0261792600 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ebdcd13c344cb6fc2d08d0261792600.addTo(map_0038a8dac7fe5c8ddd2894ddfd630340);
#
#
#             var marker_a9ec0d561a5d10bae027ace37b129627 = L.marker(
#                 [38.33344, -4.91418],
#                 {
# }
#             ).addTo(map_0038a8dac7fe5c8ddd2894ddfd630340);
#
#
#             var div_icon_e6eec984bb09668a2abfc6ad7f28ca70 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 230.49px; color: blue; text-align: center; transform: translate(-50%, 0);\&quot;\u003e|\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [230.49, 230.49],
#   &quot;iconAnchor&quot;: [6.585428571428571, 299.637],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#         var popup_e75d9935aa980ec6b1539f0df451b25d = L.popup({
#   &quot;maxWidth&quot;: 100,
# });
#
#
#
#                 var html_7b674d9071344ce56466a4d82b1b5f74 = $(`&lt;div id=&quot;html_7b674d9071344ce56466a4d82b1b5f74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Spain Installed Capacity MW: 2304.9&lt;/div&gt;`)[0];
#                 popup_e75d9935aa980ec6b1539f0df451b25d.setContent(html_7b674d9071344ce56466a4d82b1b5f74);
#
#
#
#         marker_a9ec0d561a5d10bae027ace37b129627.bindPopup(popup_e75d9935aa980ec6b1539f0df451b25d)
#         ;
#
#
#
#
#                 marker_a9ec0d561a5d10bae027ace37b129627.setIcon(div_icon_e6eec984bb09668a2abfc6ad7f28ca70);
#
#
#             var marker_7fb42b74ec1c82ec0198091290200bed = L.marker(
#                 [34.36072, -116.45088],
#                 {
# }
#             ).addTo(map_0038a8dac7fe5c8ddd2894ddfd630340);
#
#
#             var div_icon_06a528c501f99a56904ea192f48cef78 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 180.57999999999998px; color: blue; text-align: center; transform: translate(-50%, 0);\&quot;\u003e|\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [180.57999999999998, 180.57999999999998],
#   &quot;iconAnchor&quot;: [5.159428571428571, 234.754],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#         var popup_b79547c85b69018d53dc10324fb6bb0b = L.popup({
#   &quot;maxWidth&quot;: 100,
# });
#
#
#
#                 var html_f9e9eae9afedc2dcc46d2a8d0e26d4c1 = $(`&lt;div id=&quot;html_f9e9eae9afedc2dcc46d2a8d0e26d4c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;United States Installed Capacity MW: 1805.8&lt;/div&gt;`)[0];
#                 popup_b79547c85b69018d53dc10324fb6bb0b.setContent(html_f9e9eae9afedc2dcc46d2a8d0e26d4c1);
#
#
#
#         marker_7fb42b74ec1c82ec0198091290200bed.bindPopup(popup_b79547c85b69018d53dc10324fb6bb0b)
#         ;
#
#
#
#
#                 marker_7fb42b74ec1c82ec0198091290200bed.setIcon(div_icon_06a528c501f99a56904ea192f48cef78);
#
#
#             var marker_a054ff840f46eedf5efa7e29c8f9909c = L.marker(
#                 [24.462500000000002, 54.949],
#                 {
# }
#             ).addTo(map_0038a8dac7fe5c8ddd2894ddfd630340);
#
#
#             var div_icon_08a58a64824b577a35563fb745b8afba = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 80.0px; color: blue; text-align: center; transform: translate(-50%, 0);\&quot;\u003e|\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [80.0, 80.0],
#   &quot;iconAnchor&quot;: [2.2857142857142856, 104.0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#         var popup_c1da3f4a499b42710e7bc15e284384a7 = L.popup({
#   &quot;maxWidth&quot;: 100,
# });
#
#
#
#                 var html_69dcbc4efc31db1a09828569bc82686a = $(`&lt;div id=&quot;html_69dcbc4efc31db1a09828569bc82686a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;United Arab Emirates Installed Capacity MW: 800.0&lt;/div&gt;`)[0];
#                 popup_c1da3f4a499b42710e7bc15e284384a7.setContent(html_69dcbc4efc31db1a09828569bc82686a);
#
#
#
#         marker_a054ff840f46eedf5efa7e29c8f9909c.bindPopup(popup_c1da3f4a499b42710e

# %% [markdown]
# ### 2.3 What is the LCOE? How is it defined? Is it a good way to compare the economics of CSP plants?

# %% [markdown]
# The LCOE is calculated by adding up all costs of production, divided by the total amount of energy it is expected to generate
#
# $\text{LCOE} = \frac{\sum_{t=1}^{n} \frac{I_t + M_t + F_t}{(1+r)^t}}{\sum_{t=1}^{n} \frac{E_t}{(1+r)^t}}$
#
# Where:
# - $ I_t $ = Investment costs in year $ t $
# - $ M_t $ = Operating and maintenance costs in year $t$
# - $ F_t $ = Fuel costs in year $t$
# - $ E_t $ = Electricity generated in year $ t$
# - $ r$ = Discount rate
# - $ n $ = The lifetime of the plant in years
#
# Source: <https://en.wikipedia.org/wiki/Levelized_cost_of_electricity>

# %% [markdown]
# >The levelised cost of energy (LCOE) is a metric used to estimate the average cost of electricity generation over the lifetime of a power plant. The levelised cost of energy (LCOE) is a metric that can be used to determine the viability and competitiveness of an electricity generation project.
# In order to calculate the LCOE, it is necessary to consider the costs associated with building and operating a power plant over its lifetime. These costs include capital, fuel and maintenance costs.

# %% [markdown]
# > LCOE approach does not always allow for an clean and objective comparison of different plant sites. Especially with renewable energy, which is weather-dependant and not dispatchable. However, it provides a good first indicator to assess the costs of each plant.

# %% [markdown]
# ### 2.4 What is the average LCOE around the world grouped by country? Where is the lowest LCOE achieved?

# %%
df.groupby('Country')['LCOE_5_25_USD2020_per_kWh'].mean().sort_values(ascending=False).reset_index()
# Out:
#                  Country  LCOE_5_25_USD2020_per_kWh
# 0           South Africa                   2.032857
# 1              Australia                   0.640000
# 2                 Canada                   0.570000
# 3          United States                   0.287500
# 4                  Spain                   0.271633
# 5   United Arab Emirates                   0.270000
# 6                 Israel                   0.220000
# 7                Morocco                   0.215000
# 8                  India                   0.113333
# 9                  China                   0.100000
# 10               Algeria                        NaN
# 11                 Chile                        NaN
# 12               Denmark                        NaN
# 13                 Egypt                        NaN
# 14                France                        NaN
# 15               Germany                        NaN
# 16                 Italy                        NaN
# 17                Kuwait                        NaN
# 18                Mexico                        NaN
# 19          Saudi Arabia                        NaN
# 20              Thailand                        NaN
# 21                Turkey                        NaN

# %% [markdown]
# ### 2.5 Which technology is dominating in the installed CSP Plants?

# %%
technologies = df['Technology'].value_counts()
technologies.plot(kind='bar', ylabel='Count')
# Out:
# <Axes: xlabel='Technology', ylabel='Count'>

# %% [markdown]
# ### 2.6 Why could CSP be less attractive in comparison to photovoltaics? Compare Germany with Spain.

# %% [markdown]
# > It depends on the available radiation at a certain location. Spain has a higher Direct Normal Radiation compared to Germany (compare Exercise 1). The Direct Normal Radiation is the main radiation source for concentrating power plants. In comparison to photovoltaics, which can also use the Diffuse Horizontal Radiation

# %% [markdown]
# ### 2.7 Where is/are the plant sites in Germany?

# %%
df_germany = df[df['Country'] == 'Germany']
df_germany.head()
# Out:
#          Power_station Local_spelling  OpenCSP_ID  Country  Region  \
# 13  Jülich Solar Tower            NaN          14  Germany  Europe
#
#          Status  Capacity_MW  Expected_generation_GWh_per_yr Capacity_factor  \
# 13  Operational          1.5                             NaN             NaN
#
#      Technology  ...  Trough_SCA_length_m  Trough_number_of_loops  \
# 13  Power Tower  ...                  NaN                     NaN
#
#    Trough_number_of_modules_per_SCA  Trough_number_of_SCA  \
# 13                              NaN                   NaN
#
#     Trough_number_of_SCA_per_loop Construction_jobs_years  \
# 13                            NaN                     NaN
#
#    Annual_operations_jobs  \
# 13                    NaN
#
#    Additional_sources_relative_to_2019_version_of_cspGURU_and_NRELSolarPACES_as_of_31_January_2020  \
# 13                                                NaN
#
#    Latitude  Longitude
# 13   50.915      6.388
#
# [1 rows x 93 columns]

# %% [markdown]
# ## 3. Visualization

# %% [markdown]
# ### 3.1 Plot the installed capacity as a function of construction year

# %%
# Creat figure 
fig, ax = plt.subplots(1,1,figsize=(10,6))
# plot the data
y = df['Capacity_MW']
x = df['Year_construction_start']
# defining the plot typ
ax.scatter(x , y)
# Adding labels
ax.set_ylabel('Capacity [MW]')
ax.set_xlabel('Year of construction start')
# Out:
# Text(0.5, 0, 'Year of construction start')

# %% [markdown]
# ### 3.2 Evaluate the investment cost per kW as a function of the used technology.

# %%
# Specify the technologies list
techs = ["Parabolic Trough", "Linear Fresnel", "Power Tower", "Dish"]
#Specify the technologies datafreame
dftechs = df[df.Technology.isin(techs)]

# %%
# Define empty 
tech_costs = {}
for i in df.Technology.unique():
    tech_costs[i] = [
        df.loc[df.Technology == i, "Specific_cost_USD2020_per_kW"].mean(),
        df.loc[df.Technology == i, "Specific_cost_USD2020_per_kW"].std()
    ]

# %%
#Creat Figure
fig, ax = plt.subplots(1,1, figsize=(7,5))
for k, v in tech_costs.items():
    ax.bar(k, v[0])
    ax.errorbar(k, v[0], v[1], fmt='.', color='Black',
                elinewidth=2,capthick=10,errorevery=1,
                alpha=0.5, ms=4, capsize = 2)

# Adding labels
ax.set_xlabel('Technology')
ax.set_ylabel('Cost in USD$_{2020}$/kW')
ax.tick_params(axis='x', rotation=90)
# save the figure
# plt.savefig('figure.png', dpi=400, transparent=True)
plt.show()

# %% [markdown]
# ### 3.3 Evaluate the dependency of total investment cost over the storage capacity in hours

# %% [markdown]
# > Additional Task: Make a regression line/ trend line

# %%
dftower = df.loc[df.Technology == "Power Tower"]
dfpt = df.loc[df.Technology == "Parabolic Trough"]
dflf = df.loc[df.Technology == "Linear Fresnel"]

# %%
fig, ax = plt.subplots(1,1, figsize=(7,5))

ax.scatter(dftower.Storage_capacity_hours, dftower.Specific_cost_USD2020_per_kW,
           c="navy", label=f"Power Tower (n=31)")
ax.scatter(dfpt.Storage_capacity_hours, dfpt.Specific_cost_USD2020_per_kW,
           c="orange", label="Parabolic Trough (n=81)")
ax.scatter(dflf.Storage_capacity_hours, dflf.Specific_cost_USD2020_per_kW,
           c="green", label="Linear Fresnel (n=12)")

# add all technologies and drop where there are no storage_capacity_hours
dfall = dftechs.loc[pd.notna(dftechs.Storage_capacity_hours)]
dfall = dfall.loc[pd.notna(dfall.Specific_cost_USD2020_per_kW)]

# linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(
    dfall.Storage_capacity_hours, dfall.Specific_cost_USD2020_per_kW)
x = np.linspace(0, 15, 100)
y = slope * x + intercept
ax.plot(x, y, c="C3", label=f"Regression: {slope:.1f} x + {intercept:.1f}")

ax.set_xlabel('Storage Capacity in hours')
ax.set_ylabel('Cost in USD$_{2020}$/kW')
plt.legend()

# %% [markdown]
# ### 3.4 Evaluate the total investment cost as a function of total installed capacity

# %%
fig, ax = plt.subplots(1,1, figsize=(7,5))

# potential regression of the data
ax.scatter(dftower.Capacity_MW, dftower.Specific_cost_USD2020_per_kW, c="navy",
           label=f"Power Tower (n=31)")
ax.scatter(dfpt.Capacity_MW, dfpt.Specific_cost_USD2020_per_kW, c="orange",
           label="Parabolic Trough (n=81)")
ax.scatter(dflf.Capacity_MW, dflf.Specific_cost_USD2020_per_kW, c="green",
           label="Linear Fresnel (n=12)")

dfall = dftechs.loc[pd.notna(dftechs.Capacity_MW)]
dfall = dfall.loc[pd.notna(dfall.Specific_cost_USD2020_per_kW)]

slope, intercept, r_value, p_value, std_err = stats.linregress(
    dfall.Capacity_MW, dfall.Specific_cost_USD2020_per_kW)
x = np.linspace(0, 350, 100)
y = slope * x + intercept
ax.plot(x, y, c="C3", label=f"Regression: {slope:.1f} x + {intercept:.1f}")

ax.set_xlabel('Installed Capacity in MW')
ax.set_ylabel('Cost in USD$_{2020}$/kW')
plt.legend()

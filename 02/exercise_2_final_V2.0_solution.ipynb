# %% [markdown]
# > This is the second of in total 3 exercises which are examinated within the lecture "Solarthermische Kraftwerke" at Technische Universität München

# %% [markdown]
# # Second Exercise

# %% [markdown]
# In this exercise we will have a more detailed look at the power plants which are installed arround the globe.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.optimize import curve_fit
# To Visualize the data as map
import folium

# %% [markdown]
# > The first task are allready done in this exercise. To get a better overview the location sites are ploted in the map below.
#
# > Click on the marker to get the name and the year of operation of the power plant. Add more details if needed.

# %%
# Load the data as pandas dataframe
df = pd.read_csv('./csp-guru/csp-guru/csp-guru.csv')
# fix wrong data
df.loc[122,'Year_construction_start'] = 2014

# %%
df_droped_nan =df
# Split location coordinates to latitude and longitude
df_droped_nan[['Latitude', 'Longitude']] = df_droped_nan['Location_coordinates'].str.split(',', expand=True)
# COnvert string to float
df_droped_nan[['Latitude','Longitude']].astype(float)
# Drop rows with missing/NaN values
df_droped_nan.dropna(subset=['Latitude', 'Longitude'], inplace=True)
# Plot Map with folium
map = folium.Map(location=[0, 0],zoom_start = 2)
for index,row in df_droped_nan.iterrows():
    folium.Marker(
        location= [row['Latitude'], row['Longitude']], 
        popup=folium.Popup(row['Power_station'] + " Year of Operation: " + str(row['Year_operational']), parse_html=True, max_width=100),
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae5875a396a640804ba7dde56784f629 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae5875a396a640804ba7dde56784f629&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae5875a396a640804ba7dde56784f629 = L.map(
#                 &quot;map_ae5875a396a640804ba7dde56784f629&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22f6f4e0e51f7d64cc9774c5ef248131 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_22f6f4e0e51f7d64cc9774c5ef248131.addTo(map_ae5875a396a640804ba7dde56784f629);
#
#
#             var marker_d4ac575264417c09a6b6f53dc757e5d5 = L.marker(
#                 [34.863, -116.827],
#                 {}
#             ).addTo(map_ae5875a396a640804ba7dde56784f629);
#
#
#         var popup_a74f957be887bc32efe5e8b661d47130 = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_62c1f0259b1199b43f64aab87d264b3b = $(`&lt;div id=&quot;html_62c1f0259b1199b43f64aab87d264b3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Solar Electric Generating Station I Year of Operation: 1984.0&lt;/div&gt;`)[0];
#                 popup_a74f957be887bc32efe5e8b661d47130.setContent(html_62c1f0259b1199b43f64aab87d264b3b);
#
#
#
#         marker_d4ac575264417c09a6b6f53dc757e5d5.bindPopup(popup_a74f957be887bc32efe5e8b661d47130)
#         ;
#
#
#
#
#             var marker_50ef00402f2fe719acc8163b742f9060 = L.marker(
#                 [34.863, -116.827],
#                 {}
#             ).addTo(map_ae5875a396a640804ba7dde56784f629);
#
#
#         var popup_7f22e49e99d0edf3c6b4cc2503647f39 = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_8e587e970505c930fb27a6720e018fca = $(`&lt;div id=&quot;html_8e587e970505c930fb27a6720e018fca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Solar Electric Generating Station II Year of Operation: 1985.0&lt;/div&gt;`)[0];
#                 popup_7f22e49e99d0edf3c6b4cc2503647f39.setContent(html_8e587e970505c930fb27a6720e018fca);
#
#
#
#         marker_50ef00402f2fe719acc8163b742f9060.bindPopup(popup_7f22e49e99d0edf3c6b4cc2503647f39)
#         ;
#
#
#
#
#             var marker_78dc66aa5a1e63f739e7f2c55efd5a54 = L.marker(
#                 [35.014, -117.559],
#                 {}
#             ).addTo(map_ae5875a396a640804ba7dde56784f629);
#
#
#         var popup_40a07220468fea0439e6834f0b22fc0a = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_8bd07f17c32bdb98fcabaf04dad41e4a = $(`&lt;div id=&quot;html_8bd07f17c32bdb98fcabaf04dad41e4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Solar Electric Generating Station III Year of Operation: 1985.0&lt;/div&gt;`)[0];
#                 popup_40a07220468fea0439e6834f0b22fc0a.setContent(html_8bd07f17c32bdb98fcabaf04dad41e4a);
#
#
#
#         marker_78dc66aa5a1e63f739e7f2c55efd5a54.bindPopup(popup_40a07220468fea0439e6834f0b22fc0a)
#         ;
#
#
#
#
#             var marker_c0e417fefece4ffffd86620a69a872d1 = L.marker(
#                 [35.014, -117.559],
#                 {}
#             ).addTo(map_ae5875a396a640804ba7dde56784f629);
#
#
#         var popup_0089c3a4af2f2fa81368ab671ec86abb = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_a4f7f0c81fadb3a6dba3b3b53a04bbc1 = $(`&lt;div id=&quot;html_a4f7f0c81fadb3a6dba3b3b53a04bbc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Solar Electric Generating Station IV Year of Operation: 1989.0&lt;/div&gt;`)[0];
#                 popup_0089c3a4af2f2fa81368ab671ec86abb.setContent(html_a4f7f0c81fadb3a6dba3b3b53a04bbc1);
#
#
#
#         marker_c0e417fefece4ffffd86620a69a872d1.bindPopup(popup_0089c3a4af2f2fa81368ab671ec86abb)
#         ;
#
#
#
#
#             var marker_a43385c787c03da50f369f7b25ae0a26 = L.marker(
#                 [35.014, -117.559],
#                 {}
#             ).addTo(map_ae5875a396a640804ba7dde56784f629);
#
#
#         var popup_62cd6832ee2a5f3c0d66993d12c2726a = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_e0460ed6599447f44ab74d39d083b108 = $(`&lt;div id=&quot;html_e0460ed6599447f44ab74d39d083b108&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Solar Electric Generating Station V Year of Operation: 1989.0&lt;/div&gt;`)[0];
#                 popup_62cd6832ee2a5f3c0d66993d12c2726a.setContent(html_e0460ed6599447f44ab74d39d083b108);
#
#
#
#         marker_a43385c787c03da50f369f7b25ae0a26.bindPopup(popup_62cd6832ee2a5f3c0d66993d12c2726a)
#         ;
#
#
#
#
#             var marker_90b2ecaa4d7dbf9e

# %% [markdown]
# # 1. Generarl Tasks

# %% [markdown]
# ## 1.1 How many entities does the dataset have?

# %%
# Number of entities
df.shape[0]
# Out:
# 135

# %% [markdown]
# ## 1.2 Vizualize the data columns

# %%
print(df.columns)
# Out:
# Index(['Power_station', 'Local_spelling', 'OpenCSP_ID', 'Country', 'Region',
#        'Status', 'Capacity_MW', 'Expected_generation_GWh_per_yr',
#        'Capacity_factor', 'Technology', 'Hybridisation_capacity',
#        'Hybridisation_ratio', 'Hybridisation_comment',
#        'Year_construction_start', 'Year_operational',
#        'State_highest_administrative_level',
#        'Province_County_medium_administrative_level',
#        'City_lowest_administrative_level', 'Location_coordinates',
#        'DNI_kWh_per_m2_per_yr', 'Total_cost_million_currency_non_deflated',
#        'Cost_currency', 'Currency_year', 'Total_cost_million_USD2020',
#        'Specific_cost_USD2020_per_kW', 'LCOE_5_25_USD2020_per_kWh',
#        'Remuneration_currency_per_kWh', 'Support_currency',
#        'Cost_year_remuneration', 'Remuneration_USD2020_per_kWh_deflated',
#        'PPA_or_support_duration_yr', 'Support_scheme_type',
#        'Policy_support_scheme', 'Concessional_funding_other_support',
#        'Land_area_whole_station_not_solar_field_km2', 'Developer',
#        'Developer_country', 'First_owner', 'First_operator',
#        'Electricity_generation_offtaker', 'EPC', 'EPC_country',
#        'HTF_manufacturer', 'HTF_manufacturer_country', 'HTF_medium_or_product',
#        'HTF_category', 'Steam_turbine_manufacturer',
#        'Steam_turbine_manufacturer_country', 'Turbine_model',
#        'Turbine_thermodynamic_cycle', 'Power_cycle_pressure_bar',
#        'Turbine_efficiency_percent', 'Heat_exchanger_manufacturer',
#        'Heat_exchanger_manufacturer_country', 'Cooling_type',
#        'Energy_storage_type', 'Storage_capacity_hours', 'Storage_description',
#        'TES_engineering_company', 'TES_engineering_company_country',
#        'Solar_receiver_manufacturer', 'Solar_receiver_country',
#        'Solar_receiver_model', 'Tower_height_m',
#        'Number_of_heat_collecting_elements_for_trough_and_fresnel',
#        'Receiver_inlet_temperature_Celsius',
#        'Receiver_outlet_temperature_Celsius', 'SCA_or_heliostat_manufacturer',
#        'SCA_or_heliostat_manufacturer_country',
#        'SCA_or_heliostat_engineering_or_IP_owner_company',
#        'SCA_or_heliostat_engineering_or_IP_owner_company_country',
#        'SCA_or_heliostat_model', 'Reflector_mirror_manufacturer',
#        'Reflector_mirror_manufacturer_country', 'Reflector_model',
#        'Solar_mirror_area_m2', 'Solar_multiple',
#        'Number_of_heliostats_or_dishes', 'Mirror_area_per_heliostat_or_dish',
#        'Fresnel_line_width_m', 'Fresnel_number_of_lines',
#        'Fresnel_line_length_m', 'Trough_solar_collector_area_m2',
#        'Trough_SCA_length_m', 'Trough_number_of_loops',
#        'Trough_number_of_modules_per_SCA', 'Trough_number_of_SCA',
#        'Trough_number_of_SCA_per_loop', 'Construction_jobs_years',
#        'Annual_operations_jobs',
#        'Additional_sources_relative_to_2019_version_of_cspGURU_and_NRELSolarPACES_as_of_31_January_2020',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %% [markdown]
# ## 1.3 Group the dataset by 'Country' and have a look at the available entries. Are all entries always available?

# %%
# Sorts Table by Country and count the number of entries
country_count = df.groupby(['Country']).count()
country_count = country_count.sort_values(by='Country', ascending=False)
# Saves a variable to open with i.e. Data Wrangler in VS Code
country_count.head()
# Out:
#                       Power_station  Local_spelling  OpenCSP_ID  Region  \
# Country
# United States                    25               0          25      25
# United Arab Emirates              4               0           4       4
# Turkey                            1               0           1       1
# Thailand                          1               0           1       1
# Spain                            50               0          50      50
#
#                       Status  Capacity_MW  Expected_generation_GWh_per_yr  \
# Country
# United States             25           25                              19
# United Arab Emirates       4            3                               1
# Turkey                     1            1                               0
# Thailand                   1            1                               1
# Spain                     50           50                              50
#
#                       Capacity_factor  Technology  Hybridisation_capacity  \
# Country
# United States                      19          25                       0
# United Arab Emirates                1           4                       1
# Turkey                              0           1                       0
# Thailand                            1           1                       0
# Spain                              50          50                       1
#
#                       ...  Trough_SCA_length_m  Trough_number_of_loops  \
# Country               ...
# United States         ...                    4                       4
# United Arab Emirates  ...                    1                       1
# Turkey                ...                    0                       0
# Thailand              ...                    1                       1
# Spain                 ...                   37                      44
#
#                       Trough_number_of_modules_per_SCA  Trough_number_of_SCA  \
# Country
# United States                                        5                     6
# United Arab Emirates                                 1                     1
# Turkey                                               0                     0
# Thailand                                             1                     1
# Spain                                               32                    45
#
#                       Trough_number_of_SCA_per_loop  Construction_jobs_years  \
# Country
# United States                                     5                        7
# United Arab Emirates                              1                        0
# Turkey                                            0                        0
# Thailand                                          0                        1
# Spain                                            43                       33
#
#                       Annual_operations_jobs  \
# Country
# United States                              7
# United Arab Emirates                       0
# Turkey                                     0
# Thailand                                   1
# Spain                                     36
#
#                       Additional_sources_relative_to_2019_version_of_cspGURU_and_NRELSolarPACES_as_of_31_January_2020  \
# Country
# United States                                                         8
# United Arab Emirates                                                  2
# Turkey                                                                0
# Thailand                                                              0
# Spain                                                                 0
#
#                       Latitude  Longitude
# Country
# United States               25         25
# United Arab Emirates         4          4
# Turkey                       1          1
# Thailand                     1          1
# Spain                       50         50
#
# [5 rows x 92 columns]

# %% [markdown]
# > Answer: Not for all locaiton sites all informaiton is available

# %% [markdown]
# ## 1.4 Is the industry transparent with the data of the concentraiting power plants?

# %% [markdown]
# > Yes, it is quite transparent. A lot of information is given, i.e. general information of total energy generation, coordinates, year of construction. Additional to this information the inlet temperature of the collectors, the specific cycle for energy transition, the total cost for building and LCOE are given. Therefore, the industry in the concentraiting solar power plants is transparent.

# %% [markdown]
# ## 1.5 Are there any new power plants, which are currently under construciton, but not included in the dataset?

# %% [markdown]
# > https://www.solarpaces.org/

# %% [markdown]
# ## 2.1 In which country are the moste Conentratiting Solar Power Plants installed? Why is this so?

# %%
[df['Country'].groupby(df['Country']).count().idxmax(), df['Country'].groupby(df['Country']).count().max()]
# Out:
# ['Spain', 50]

# %%
df['Country'].value_counts()
# Out:
# Country
# Spain                   50
# United States           25
# China                   14
# South Africa             7
# India                    7
# Australia                5
# Morocco                  4
# United Arab Emirates     4
# Italy                    3
# Israel                   2
# Saudi Arabia             2
# France                   2
# Kuwait                   1
# Mexico                   1
# Denmark                  1
# Turkey                   1
# Canada                   1
# Thailand                 1
# Egypt                    1
# Algeria                  1
# Germany                  1
# Chile                    1
# Name: count, dtype: int64

# %% [markdown]
#  History Excurs:
#
# >"In September 2002, Spain was the first European country to introduce a “feed-in tariff” funding system for solar thermal power. This funding system granted a premium on top of the electricity pool price of 12 € cents for each kWh output of a solar thermal plant between 100 kW and 50 MW of capacity, which could be changed every four years. But this amount proved not bankable nor did it cover the cost and risks to make the first projects feasible.
# >The Royal Decree 436/2004 introduced two alternative remuneration options for new CSP installed capacity. Solar thermal electricity generators who sell their production to a distributor receive as fixed tariff 300% of the reference price (7.2 € cents/kWh) during the first 25 years and 240% afterwards.
# >Solar thermal electricity generators who sell their electricity on the free market receive the negotiated market price of electricity, a premium of 250% of the reference price during the first 25 years, 200% afterwards, and an incentive of 10%."
# Information taken from : https://www.solarpaces.org/worldwide-csp/csp-potential-solar-thermal-energy-by-country/spain/

# %% [markdown]
# ## 2.2 Which country has the biggest installed capacity of solar concentrating power plants?

# %%
# Convert Latitude to numeric, coercing errors to NaN
df['Latitude'] = pd.to_numeric(df['Latitude'], errors='coerce')

# Group by Country and calculate mean Latitude
mean_latitude = df.groupby('Country')['Latitude'].mean().reset_index()

# %%
# Convert Latitude to numeric, coercing errors to NaN
df['Longitude'] = pd.to_numeric(df['Longitude'], errors='coerce')

# Group by Country and calculate mean Latitude
mean_longitude = df.groupby('Country')['Longitude'].mean().reset_index()
mean_coordinates = pd.merge(mean_latitude, mean_longitude, on='Country')
# Intention to isolate the coordinates of the countries

# %%
#Groub by Country and calculate the total capacity
country_capacity = df.groupby('Country')['Capacity_MW'].sum().reset_index()
# Sort the table descending
country_capacity = country_capacity.sort_values(by='Capacity_MW', ascending=False)
# Merge the two dataframes
country_capacity = pd.merge(country_capacity,mean_coordinates, on='Country')
country_capacity.head(25)
# Out:
#                  Country  Capacity_MW   Latitude   Longitude
# 0                  Spain       2304.9  38.333440   -4.914180
# 1          United States       1805.8  34.360720 -116.450880
# 2   United Arab Emirates        800.0  24.462500   54.949000
# 3           South Africa        600.0 -28.513354   21.465312
# 4                  China        596.0  39.425342   99.767241
# 5                  India        342.5  25.986857   74.532143
# 6                Morocco        333.0  31.584000   -6.245500
# 7                 Israel        231.0  30.964500   34.706000
# 8                  Chile        110.0 -22.771000  -69.479000
# 9           Saudi Arabia         93.0  29.689800   37.162500
# 10                Kuwait         50.0  29.139000   47.018000
# 11               Algeria         20.0  33.124000    3.357000
# 12                 Egypt         20.0  29.279000   31.249000
# 13                Mexico         12.0  31.326000 -109.549000
# 14             Australia          9.6 -32.811600  146.865200
# 15                France          9.3  42.485000    2.017500
# 16                 Italy          6.1  39.746000   14.664000
# 17               Denmark          5.5  57.254000    9.989000
# 18              Thailand          5.0  14.334000   99.709000
# 19               Germany          1.5  50.915000    6.388000
# 20                Turkey          1.4  36.865000   34.610000
# 21                Canada          1.1  50.040000 -110.720000

# %%
# Function to determine the size of the icon
def get_icon_size(capacity):
    return max(capacity/10 ,15) # Scale size as needed

# Create a Folium map
map_total_capacity = folium.Map(location=[0, 0], zoom_start=2)

# Add markers with adjustable size
for index, row in country_capacity.iterrows():
    icon_size = get_icon_size(row['Capacity_MW'])
    
    # Set the anchor point for the icon based on the icon size
    icon_anchor = (icon_size / 35, icon_size*1.3)  # Centered horizontally, bottom anchored

    # Create a DivIcon with custom size and centering
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(f"{row['Country']} Installed Capacity MW: {row['Capacity_MW']}", parse_html=True, max_width=100),
        icon=folium.DivIcon(
            html=f'<div style="font-size: {icon_size}px; color: blue; text-align: center; transform: translate(-50%, 0);">|</div>',  # Using a circle >⬤< character can also be used
            icon_size=(icon_size, icon_size),
            icon_anchor=icon_anchor
        )
    ).add_to(map_total_capacity)

# Display the map
map_total_capacity
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fd406d819521df87ec8519dbb9d6af8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fd406d819521df87ec8519dbb9d6af8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fd406d819521df87ec8519dbb9d6af8 = L.map(
#                 &quot;map_9fd406d819521df87ec8519dbb9d6af8&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9d43d611e354b66b3b42464fb30e011 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c9d43d611e354b66b3b42464fb30e011.addTo(map_9fd406d819521df87ec8519dbb9d6af8);
#
#
#             var marker_4203f78c47e814e0f86d280e15da622c = L.marker(
#                 [38.33344, -4.91418],
#                 {}
#             ).addTo(map_9fd406d819521df87ec8519dbb9d6af8);
#
#
#             var div_icon_fd31e09c8f1b8e322da7fa6049c4d27a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 230.49px; color: blue; text-align: center; transform: translate(-50%, 0);\&quot;\u003e|\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [6.585428571428571, 299.637], &quot;iconSize&quot;: [230.49, 230.49]});
#             marker_4203f78c47e814e0f86d280e15da622c.setIcon(div_icon_fd31e09c8f1b8e322da7fa6049c4d27a);
#
#
#         var popup_f45ab35843d309f153e1fdeaf00e596d = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_2a3001659e5ae437093c87d83a080b89 = $(`&lt;div id=&quot;html_2a3001659e5ae437093c87d83a080b89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Spain Installed Capacity MW: 2304.9&lt;/div&gt;`)[0];
#                 popup_f45ab35843d309f153e1fdeaf00e596d.setContent(html_2a3001659e5ae437093c87d83a080b89);
#
#
#
#         marker_4203f78c47e814e0f86d280e15da622c.bindPopup(popup_f45ab35843d309f153e1fdeaf00e596d)
#         ;
#
#
#
#
#             var marker_ffab0fe709f102dfa6c47396e87c1446 = L.marker(
#                 [34.36072, -116.45088],
#                 {}
#             ).addTo(map_9fd406d819521df87ec8519dbb9d6af8);
#
#
#             var div_icon_59406a0800207e454cd8ff0d4fb45875 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 180.57999999999998px; color: blue; text-align: center; transform: translate(-50%, 0);\&quot;\u003e|\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5.159428571428571, 234.754], &quot;iconSize&quot;: [180.57999999999998, 180.57999999999998]});
#             marker_ffab0fe709f102dfa6c47396e87c1446.setIcon(div_icon_59406a0800207e454cd8ff0d4fb45875);
#
#
#         var popup_f2e012caed00ec8ccdde112fe3a6aa34 = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_7ccfe94aa5a83709f6d353ff583bde67 = $(`&lt;div id=&quot;html_7ccfe94aa5a83709f6d353ff583bde67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;United States Installed Capacity MW: 1805.8&lt;/div&gt;`)[0];
#                 popup_f2e012caed00ec8ccdde112fe3a6aa34.setContent(html_7ccfe94aa5a83709f6d353ff583bde67);
#
#
#
#         marker_ffab0fe709f102dfa6c47396e87c1446.bindPopup(popup_f2e012caed00ec8ccdde112fe3a6aa34)
#         ;
#
#
#
#
#             var marker_a0dbf1c63c412d230276badca1f90aaf = L.marker(
#                 [24.462500000000002, 54.949],
#                 {}
#             ).addTo(map_9fd406d819521df87ec8519dbb9d6af8);
#
#
#             var div_icon_cc7aa569c625fda3cfcb5d220d9a402c = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 80.0px; color: blue; text-align: center; transform: translate(-50%, 0);\&quot;\u003e|\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [2.2857142857142856, 104.0], &quot;iconSize&quot;: [80.0, 80.0]});
#             marker_a0dbf1c63c412d230276badca1f90aaf.setIcon(div_icon_cc7aa569c625fda3cfcb5d220d9a402c);
#
#
#         var popup_4af4450667b2ba570ad1788d28f2f04e = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_f9617b3208e00576d47905b94e4600bf = $(`&lt;div id=&quot;html_f9617b3208e00576d47905b94e4600bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;United Arab Emirates Installed Capacity MW: 800.0&lt;/div&gt;`)[0];
#                 popup_4af4450667b2ba570ad1788d28f2f04e.setContent(html_f9617b3208e00576d47905b94e4600bf);
#
#
#
#         marker_a0dbf1c63c412d230276badca1f90aaf.bindPopup(popup_4af4450667b2ba570ad1788d28f2f04e)
#         ;
#
#
#
#
#             var marker_1af3932f4598e76cd241361d5a1f0568 = L.marker(
#                 [-28.513353714285717, 21.465311714285715],
#                 {}
#             ).addTo(map_9fd406d819521df87ec8519dbb9d6af8);

# %% [markdown]
# ## 2.3 What is meant with LCOE? Is it a good way to compair solar concentraiting power plants?

# %% [markdown]
# >The levelised cost of energy (LCOE) is a metric used to gauge the average cost of electricity generation over the lifetime of an energy asset. The levelised cost of energy (LCOE) is a metric that can be used to determine the viability and competitiveness of an electricity generation project. It can also be employed as an indicator for heating and cooling projects.
# In order to calculate the LCOE, it is necessary to consider the costs associated with building and operating an energy asset over its lifetime. These costs include capital, fuel and maintenance costs. It should be noted that different LCOE models and tools use different variables. In addition, the LCOE formulae that are used are not all the same. Some LCOE formulas are more complex than others. The LCOE is also known as the "levelised cost of electricity".

# %% [markdown]
# > LCOE approach does not always allow for an clean and objective comparison of different plant sites. Aspects such as the ability to modify the environment, the degree of autonomy, and the qualification of the available workforce must also be considered.

# %% [markdown]
# ## 2.4 What are the average LCOE arround the world grouped by country? Does Spain also have the lowest LCOE?

# %%
df.groupby('Country')['LCOE_5_25_USD2020_per_kWh'].mean().sort_values(ascending=False).reset_index()
# Out:
#                  Country  LCOE_5_25_USD2020_per_kWh
# 0           South Africa                   2.032857
# 1              Australia                   0.640000
# 2                 Canada                   0.570000
# 3          United States                   0.287500
# 4                  Spain                   0.271633
# 5   United Arab Emirates                   0.270000
# 6                 Israel                   0.220000
# 7                Morocco                   0.215000
# 8                  India                   0.113333
# 9                  China                   0.100000
# 10               Algeria                        NaN
# 11                 Chile                        NaN
# 12               Denmark                        NaN
# 13                 Egypt                        NaN
# 14                France                        NaN
# 15               Germany                        NaN
# 16                 Italy                        NaN
# 17                Kuwait                        NaN
# 18                Mexico                        NaN
# 19          Saudi Arabia                        NaN
# 20              Thailand                        NaN
# 21                Turkey                        NaN

# %% [markdown]
# ## 2.5 What is the most used technology in Solar Concentraiting Power Plants?

# %%
technologies = df['Technology'].value_counts()
technologies.plot(kind='bar')
# Out:
# <Axes: xlabel='Technology'>

# %% [markdown]
# ## 2.6 Why is it not attractive to install Conentraiting Solar Power Plants in comparison to photovoltaics? Compair Germany with Spain.

# %% [markdown]
# > It depends on the available radaiation at a certain location. Spain has a higher Direct Normal Radiation compaired to Germany (Compair Exercise 1). The Direct Normal Radiation is the main radiation source for conenctraiting power plants. In comparison to photovoltaics, which can also use the Diffuse Horizontal Radiation

# %% [markdown]
# ## 2.7 Where is/are the plant sites in Germany?

# %%
df_germany = df[df['Country'] == 'Germany']
df_germany.head()
# Out:
#          Power_station Local_spelling  OpenCSP_ID  Country  Region  \
# 13  Jülich Solar Tower            NaN          14  Germany  Europe
#
#          Status  Capacity_MW  Expected_generation_GWh_per_yr Capacity_factor  \
# 13  Operational          1.5                             NaN             NaN
#
#      Technology  ...  Trough_SCA_length_m  Trough_number_of_loops  \
# 13  Power Tower  ...                  NaN                     NaN
#
#    Trough_number_of_modules_per_SCA  Trough_number_of_SCA  \
# 13                              NaN                   NaN
#
#     Trough_number_of_SCA_per_loop Construction_jobs_years  \
# 13                            NaN                     NaN
#
#    Annual_operations_jobs  \
# 13                    NaN
#
#    Additional_sources_relative_to_2019_version_of_cspGURU_and_NRELSolarPACES_as_of_31_January_2020  \
# 13                                                NaN
#
#    Latitude  Longitude
# 13   50.915      6.388
#
# [1 rows x 93 columns]

# %% [markdown]
# # 3. Vizualisation

# %% [markdown]
# ## 3.1 Show the dependecy of the construction year with the installed capacity:

# %%
# Creat figure 
fig, ax = plt.subplots(1,1,figsize=(10,6))
# plot the data
y = df['Capacity_MW']
x = df['Year_construction_start']
# defining the plot typ
ax.scatter(x , y)
# Adding labels
ax.set_ylabel('Capacity [MW]')
ax.set_xlabel('Year of construction start')
# Out:
# Text(0.5, 0, 'Year of construction start')

# %% [markdown]
# ## 3.2 Evaluate the investment cost per kW over the used technology for collecting the radiation.

# %%
# Specify the technologies list
techs = ["Parabolic Trough", "Linear Fresnel", "Power Tower", "Dish"]
#Specify the technologies datafreame
dftechs = df[df.Technology.isin(techs)]

# %%
# Define empty 
tech_costs = {}
for i in df.Technology.unique():
    tech_costs[i] = [
        df.loc[df.Technology == i, "Specific_cost_USD2020_per_kW"].mean(),
        df.loc[df.Technology == i, "Specific_cost_USD2020_per_kW"].std()
    ]

# %%
#Creat Figure
fig, ax = plt.subplots(1,1, figsize=(7,5))
for k, v in tech_costs.items():
    ax.bar(k, v[0])
    ax.errorbar(k, v[0], v[1], fmt='.', color='Black', elinewidth=2,capthick=10,errorevery=1, alpha=0.5, ms=4, capsize = 2)

# Adding labels
ax.set_xlabel('Technology')
ax.set_ylabel('Cost in USD$_{2020}$/kW')
ax.tick_params(axis='x', rotation=90)
# save the figure
# plt.savefig('figure.png', dpi=400, transparent=True)
plt.show()

# %% [markdown]
# ## 3.3 Evaluate the Dependecy of Total Investment Cost over the Storage Capacity in Hours

# %% [markdown]
# > Additional Task: Make a regression line/ trend line

# %%
dftower = df.loc[df.Technology == "Power Tower"]
dfpt = df.loc[df.Technology == "Parabolic Trough"]
dflf = df.loc[df.Technology == "Linear Fresnel"]

# %%
fig, ax = plt.subplots(1,1, figsize=(7,5))

ax.scatter(dftower.Storage_capacity_hours, dftower.Specific_cost_USD2020_per_kW, c="navy", label=f"Power Tower (n=31)")
ax.scatter(dfpt.Storage_capacity_hours, dfpt.Specific_cost_USD2020_per_kW, c="orange", label="Parabolic Trough (n=81)")
ax.scatter(dflf.Storage_capacity_hours, dflf.Specific_cost_USD2020_per_kW, c="green", label="Linear Fresnel (n=12)")

# add all technologies and drop where there are no storage_capacity_hours
dfall = dftechs.loc[pd.notna(dftechs.Storage_capacity_hours)]
dfall = dfall.loc[pd.notna(dfall.Specific_cost_USD2020_per_kW)]

# linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(
    dfall.Storage_capacity_hours, dfall.Specific_cost_USD2020_per_kW)
x = np.linspace(0, 15, 100)
y = slope * x + intercept
ax.plot(x, y, c="C3", label=f"Regression: {slope:.1f} x + {intercept:.1f}")

ax.set_xlabel('Storage Capacity in hours')
ax.set_ylabel('Cost in USD$_{2020}$/kW')
plt.legend()

# %% [markdown]
# ## 3.4 Evaluate the Total Investment Cost over the Total Installed Capacity in Hours

# %%
fig, ax = plt.subplots(1,1, figsize=(7,5))

# potential regression of the data
ax.scatter(dftower.Capacity_MW, dftower.Specific_cost_USD2020_per_kW, c="navy", label=f"Power Tower (n=31)")
ax.scatter(dfpt.Capacity_MW, dfpt.Specific_cost_USD2020_per_kW, c="orange", label="Parabolic Trough (n=81)")
ax.scatter(dflf.Capacity_MW, dflf.Specific_cost_USD2020_per_kW, c="green", label="Linear Fresnel (n=12)")

dfall = dftechs.loc[pd.notna(dftechs.Capacity_MW)]
dfall = dfall.loc[pd.notna(dfall.Specific_cost_USD2020_per_kW)]

slope, intercept, r_value, p_value, std_err = stats.linregress(
    dfall.Capacity_MW, dfall.Specific_cost_USD2020_per_kW)
x = np.linspace(0, 350, 100)
y = slope * x + intercept
ax.plot(x, y, c="C3", label=f"Regression: {slope:.1f} x + {intercept:.1f}")

ax.set_xlabel('Installed Capacity in MW')
ax.set_ylabel('Cost in USD$_{2020}$/kW')
plt.legend()
